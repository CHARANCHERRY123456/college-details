# %%
import pandas as pd

# %%
prev_df = pd.read_csv("prev_the_data.csv");
prev_df
# Out:
#            ID                       NAME  GENDER    CET HT NO. STREAM  \
# 0     R200001  POSA VENKATA SIVA SHANKAR    MALE  2.111020e+09  M.P.C
# 1     R200002    NANDINENI HARSHAVARDHAN    MALE  2.212027e+09  M.P.C
# 2     R200003            GAJULA HARSHITH    MALE  2.715001e+09  M.P.C
# 3     R200004  KONANGI LAKSHMI NARASIMHA    MALE  2.010015e+09  M.P.C
# 4     R200005     ELUGOTI HARSHA VARDHAN    MALE  2.212026e+09  M.P.C
# ...       ...                        ...     ...           ...    ...
# 1089  R201107           NANDYALA SANDHYA  FEMALE  2.111020e+09  M.P.C
# 1090  R201108        MANDI SAI JASHWANTH    MALE  2.010001e+09  M.P.C
# 1091  R201109            KOMARALA RUPESH    MALE  2.111018e+09  M.P.C
# 1092  R201110              P VIJAY LAXMI  FEMALE  2.111064e+09  M.P.C
# 1093  R201111                  ABHINAY D    MALE  2.212026e+09  M.P.C
#
#      Class(p1) CASTE            Class(p2)         DOB  \
# 0         G004  BC-B  Class-12 (S017-AB1)  10/06/2003
# ...

# %%
df = pd.read_csv("the_data.csv")

# %%
prev_df['Image']
# Out:
# 0       http://210.212.217.214/r_20_twenty/R200001.jpg
# 1       http://210.212.217.214/r_20_twenty/R200002.jpg
# 2       http://210.212.217.214/r_20_twenty/R200003.jpg
# 3       http://210.212.217.214/r_20_twenty/R200004.jpg
# 4       http://210.212.217.214/r_20_twenty/R200005.jpg
#                              ...
# 1089    http://210.212.217.214/r_20_twenty/R201107.jpg
# 1090    http://210.212.217.214/r_20_twenty/R201108.jpg
# 1091    http://210.212.217.214/r_20_twenty/R201109.jpg
# 1092    http://210.212.217.214/r_20_twenty/R201110.jpg
# 1093    http://210.212.217.214/r_20_twenty/R201111.jpg
# Name: Image, Length: 1094, dtype: object

# %%
df['IMAGE'] = prev_df['Image']

# %%
df.columns
# Out:
# Index(['ID', 'NAME', 'GENDER', 'CET HT NO.', 'pucbranch', 'Class(p1)', 'CASTE',
#        'Class(p2)', 'DOB', 'BRANCH', 'FATHER', 'MANDAL', 'DISTRICT', 'SCHOOL',
#        'PHONE2', 'SSC', 'SSC BOARD', 'PHONE', 'MOTHER', 'BLOOD GROUP',
#        'Parent', 'ADDRESS', 'e1sem1', 'e1sem2', 'e2sem1', 'e2sem2', 'BRANCH.1',
#        'CGPA', 'IMAGE'],
#       dtype='object')

# %%
prev_df.columns
# Out:
# Index(['ID', 'NAME', 'GENDER', 'CET HT NO.', 'STREAM', 'Class(p1)', 'CASTE',
#        'Class(p2)', 'DOB', 'BRANCH', 'Image', 'FATHER', 'MANDAL', 'DISTRICT',
#        'SCHOOL', 'PHONE'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'NAME', 'GENDER', 'CET HT NO.', 'STREAM', 'Class(p1)', 'CASTE',
#        'Class(p2)', 'DOB', 'BRANCH', 'FATHER', 'MANDAL', 'DISTRICT', 'SCHOOL',
#        'PHONE2', 'SSC', 'SSC BOARD', 'PHONE', 'MOTHER', 'BLOOD GROUP',
#        'Parent', 'ADDRESS', 'e1sem1', 'e1sem2', 'e2sem1', 'e2sem2', 'BRANCH.1',
#        'CGPA', 'Image'],
#       dtype='object')

# %%
df.rename(columns={
    "IMAGE" : "Image"
} , inplace=True)

# %%
df[(df['NAME']=="UKKISILA SWATHI")]['PHONE2']
# Out:
# 64    7386542619
# Name: PHONE2, dtype: int64

# %%
# Out:
# 0

# %%
prev_df[prev_df['PHONE'] == 0].count()
# Out:
# ID            669
# NAME          669
# GENDER        669
# CET HT NO.    669
# STREAM        669
# Class(p1)     669
# CASTE         669
# Class(p2)     669
# DOB           669
# BRANCH        669
# Image         669
# FATHER        669
# MANDAL        668
# DISTRICT      669
# SCHOOL        669
# PHONE         669
# dtype: int64

# %%
df['PHONE'].fillna("Not Found" , inplace=True)

# %%
df.fillna("Not Found")
# Out:
#            ID                       NAME  GENDER  CET HT NO. STREAM Class(p1)  \
# 0     R200001  POSA VENKATA SIVA SHANKAR    MALE  2111020143  M.P.C      G004
# 1     R200002    NANDINENI HARSHAVARDHAN    MALE  2212027156  M.P.C      G004
# 2     R200003            GAJULA HARSHITH    MALE  2715001069  M.P.C      G005
# 3     R200004  KONANGI LAKSHMI NARASIMHA    MALE  2010015101  M.P.C      G004
# 4     R200005     ELUGOTI HARSHA VARDHAN    MALE  2212026173  M.P.C      G006
# ...       ...                        ...     ...         ...    ...       ...
# 1089  R201107           NANDYALA SANDHYA  FEMALE  2111020018  M.P.C      G008
# 1090  R201108        MANDI SAI JASHWANTH    MALE  2010001065  M.P.C      G011
# 1091  R201109            KOMARALA RUPESH    MALE  2111018166  M.P.C      G012
# 1092  R201110              P VIJAY LAXMI  FEMALE  2111064055  M.P.C      G008
# 1093  R201111                  ABHINAY D    MALE  2212026064  M.P.C      G008
#
# ...

# %%
df.to_csv("the_data.csv")

# %%
df
# Out:
#            ID                       NAME  GENDER  CET HT NO. STREAM Class(p1)  \
# 0     R200001  POSA VENKATA SIVA SHANKAR    MALE  2111020143  M.P.C      G004
# 1     R200002    NANDINENI HARSHAVARDHAN    MALE  2212027156  M.P.C      G004
# 2     R200003            GAJULA HARSHITH    MALE  2715001069  M.P.C      G005
# 3     R200004  KONANGI LAKSHMI NARASIMHA    MALE  2010015101  M.P.C      G004
# 4     R200005     ELUGOTI HARSHA VARDHAN    MALE  2212026173  M.P.C      G006
# ...       ...                        ...     ...         ...    ...       ...
# 1089  R201107           NANDYALA SANDHYA  FEMALE  2111020018  M.P.C      G008
# 1090  R201108        MANDI SAI JASHWANTH    MALE  2010001065  M.P.C      G011
# 1091  R201109            KOMARALA RUPESH    MALE  2111018166  M.P.C      G012
# 1092  R201110              P VIJAY LAXMI  FEMALE  2111064055  M.P.C      G008
# 1093  R201111                  ABHINAY D    MALE  2212026064  M.P.C      G008
#
# ...
